# %% [markdown]
# <a href="https://colab.research.google.com/github/DakkaliBhumika/CSEP/blob/main/01-07-22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import h5py
import timeit
x= np.linspace(-np.pi,np.pi,100)
y= np.sin(x)
my_file= open('sin_data.txt','w')
my_file.write('#This is my sine function.\n')
for i in range(len(x)):
  my_file.write('%f \t %f \n'%(x[i],y[i]))
my_file.close()
data= np.loadtxt("sin_data.txt")
#print(data)
#rint(data[:,0])#print x values
#print(data[:,1])#print y values
print("binary h5###########")
data_array=np.vstack((x,y))
np.save('sin_data_bin',data_array)
data_bin= np.load('sin_data_bin.npy')
print(data_bin)
print("binary h5################")
write_file= h5py.File('abc.h5','w')
write_file['data_1']= data_array
write_file.close()
read_file=h5py.File('abc.h5')
z=read_file[data_1]
start=timeit.default_timer()
#read_file = h5py.File(‘data_set.h5’)
data = read_file[‘data_1’]
data = np.array(data)
t = data[:,0]
x = data[:,1]
stop = timeit.default_timer()
print (“ Time taken (in econds) = ”, stop-start)
# Out:
#   File "<ipython-input-16-6b52ec29a879>", line 29
#     data = read_file[‘data_1’]
#                             ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 5, 3
# figure of the size 5in x 3in
x = np.linspace(-1,1,10)
y = x**2
y1 = x**3
plt.plot(x,y, 'y.', label = r'$y=x^2$')
plt.plot(x,y1, lw = 3, color = 'r', label = r'$y=x^3$')
plt.axhline(0, color='k') # draw hor axis
plt.axvline(0, color='k') # draw vertical axis
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.xlabel(r'$x$', fontsize=50)
plt.ylabel(r'$y$', fontsize=50)
plt.legend(loc=4)
plt.savefig('plot2d.pdf')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 7, 5
# figure of the size 5in x 3in
x = np.linspace(-1,1,10)
y = x**4
y1 = x**5
plt.plot(x,y, 'r.', label = r'$y=x^2$')
plt.plot(x,y1, lw = 6, color = 'g', label = r'$y=x^3$')
plt.axhline(0, color='k') # draw hor axis
plt.axvline(0, color='k') # draw vertical axis
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.xlabel(r'$x$', fontsize=20)
plt.ylabel(r'$y$', fontsize=20)
plt.legend(loc=4)
plt.savefig('plot2d.pdf')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
# Vector plot
x = np.linspace(-2,2,10)
y = np.linspace(-2,2,10)
xv, yv = np.meshgrid(x,y)
# meshgrid is a 2D grid: (xv,yv) provides the coordinate at points a mesh of Nx*Ny grid.
plt.figure()
plt.quiver(xv, yv, -xv**3, -yv**3)
# quiver = array: At point (xv,yv), make vector of (-xv**3,-yv**3).plt.xlabel(r'$x$', fontsize=20)
plt.ylabel(r'$y$', fontsize=20)
plt.xticks(np.linspace(-2, 2, 5, endpoint=True))
plt.yticks(np.linspace(-2, 2, 5, endpoint=True))
plt.axes().set_aspect('equal')
plt.tight_layout()
plt.savefig("vector.pdf")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
plt.gca(projection='3d') #gca = get current axis
#Vector plot
x= np.linspace(-10,10,6)
y= np.linspace(-10,10,6)
z= np.linspace(-10,10,6)
xv, yv,zv = np.meshgrid(x,y,z)
# meshgrid is a 3D grid: (xv,yv,zv)=coordinate
plt.quiver(xv, yv, zv, -xv, -yv, -zv)
plt.savefig("vector3d.pdf")
plt.show()

# %%
##surface plot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
rcParams['figure.figsize'] = 8, 8
## 3D surface_plot
fig = plt.figure()
axes = fig.gca(projection='3d') #gca = get current axis
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
xv, yv = np.meshgrid(x,y)
z = (xv**2 + yv**2)/2  
# surface_plot with color grading and color bar
p = axes.plot_surface(xv,yv,z, rstride=4, cstride=4, cmap=cm.RdBu,linewidth=0, antialiased=False)
fig.colorbar(p,shrink=0.5)
axes.set_xlabel('$x$',fontsize=15)
axes.set_ylabel('$y$',fontsize=15)
axes.set_zlabel('$z$',fontsize=15)
plt.tight_layout()
fig.savefig('surface.pdf') 
plt.show()

# %%
#Contour plot
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 5, 5
### contour plot
#
plt.figure()
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xv, yv = np.meshgrid(x,y)
#z = (xv**2 + yv**2)/2
z = -np.log(np.sqrt((xv**2 + yv**2)))
curves = plt.contour(xv,yv,z,7000)
plt.colorbar()
plt.xlabel('$x$',size=20)
plt.ylabel('$y$',size=20)
plt.axes().set_aspect('equal')
plt.tight_layout()
plt.savefig("contour.pdf")
plt.show()
# Out:
# Locator attempting to generate 5746 ticks ([-2.6496, ..., 1.9464000000000001]), which exceeds Locator.MAXTICKS (1000).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 5, 5
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
xv, yv = np.meshgrid(x,y)
z = (xv**2 + yv**2)/2
plt.imshow(z, vmin=abs(z).min(), vmax=abs(z).max(),
extent=[-1,1,-1,1])
plt.colorbar()
plt.xlabel('$x$',size=20)
plt.ylabel('$y$',size=20)
plt.axes().set_aspect('equal')
plt.tight_layout()
plt.savefig("density1.pdf")
plt.show()
plt.figure()
plt.pcolor(xv,yv, z)
plt.colorbar()
plt.xlabel('$x$',size=20)
plt.ylabel('$y$',size=20)
plt.axes().set_aspect('equal')
plt.tight_layout()
plt.savefig("density2.pdf")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
